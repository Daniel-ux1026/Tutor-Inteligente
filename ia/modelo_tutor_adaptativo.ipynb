# %% [markdown]
# # Tutor Inteligente Adaptativo - Árbol de decisión
# Notebook reproducible del modelo multiclase. El dataset es sintético y contiene 620 registros.

# %%
from train_model import generate_dataset, train_and_export
dataset = generate_dataset()
dataset.head(), dataset.shape

# %%
metrics = train_and_export(random_state=42)
{key: metrics[key] for key in ['accuracy', 'precision_weighted', 'recall_weighted', 'f1_weighted']}

# %% [markdown]
# Los artefactos generados se guardan en `models/` y `reports/`. Las métricas provienen del 20 % reservado para prueba y no deben interpretarse como validación pedagógica con estudiantes reales.
